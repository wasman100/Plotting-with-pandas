# %% [markdown]
# # Homework: Plotting With Pandas

# %% [markdown]
# #### #1. Import `pandas` and `matplotlib.pyplot`

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The following simply makes some of the figures and font sizes a bit larger (assuming you imported `matplotlib` as `plt`):

# %%
plt.rcParams['figure.figsize'] = (9, 8)
plt.rcParams['font.size'] = 12

# %% [markdown]
# #### #2. Read in the NBA players `csv` into a variable called `nba`.

# %% [markdown]
# This is a data set of NBA players from 2015. The filename is `nba_players_2015.csv`.

# %%
NBA = pd.read_csv('nba_players_2015.csv',delimiter = ',')

# %% [markdown]
# #### #3. Look at the first five rows of the data set

# %%
NBA.head()
# Out:
#    season_end         player pos  age bref_team_id   g  gs    mp   fg   fga  \
# 0        2015     Quincy Acy   F   24          NYK  52  21  19.2  2.2   4.6
# 1        2015   Jordan Adams   G   20          MEM  18   0   7.3  1.0   2.1
# 2        2015   Steven Adams   C   21          OKC  51  50  24.2  3.0   5.5
# 3        2015    Jeff Adrien   F   28          MIN  17   0  12.6  1.1   2.6
# 4        2015  Arron Afflalo   G   29          TOT  60  54  32.5  5.0  11.8
#
#    ...  TOV%  USG%  OWS  DWS   WS  WS/48  OBPM  DBPM  BPM  VORP
# 0  ...  15.1  14.7  0.6  0.5  1.0  0.050  -2.6  -0.7 -3.4  -0.3
# 1  ...  15.9  17.7  0.0  0.2  0.2  0.076  -2.3   1.8 -0.5   0.0
# 2  ...  19.2  14.8  1.0  1.8  2.8  0.109  -2.0   2.0 -0.1   0.6
# 3  ...  12.9  14.1  0.2  0.2  0.4  0.093  -2.6   0.8 -1.8   0.0
# 4  ...  10.9  19.6  1.4  0.7  2.1  0.051  -0.2  -1.4 -1.6   0.2
#
# [5 rows x 49 columns]

# %% [markdown]
# #### #4. Create a histogram of the `age` column.

# %%
NBA['age'].value_counts().sort_index().plot(kind='hist');

# %% [markdown]
# #### #5. Create a histogram of the `age` column, but change the number of bins to 20.

# %%
NBA['age'].value_counts().sort_index().plot(kind='hist', bins=20);

# %% [markdown]
# #### #6. Discuss the difference in the two plots and the implications.

# %% [markdown]
# it is able to divide the data up so u can see more indivual ages instead of clomping it all together getting a wider view of data

# %% [markdown]
# #### #7.  Plot the number of guards, centers, and forwards in this data set.

# %%
NBA['pos'].value_counts().sort_index().plot(kind='bar');

# %% [markdown]
# #### #8. Create a new column, `pos_as_num`, by using the mapping dictionary `{ C:5, G:1, F:3 }`. Then create a scatter matrix plot with the `pos_as_num`, `pts`, `age`, and `fg` columns.
#
# **Hint:** You'll have to do the same trick with `map` as we did in class, with converting the type of avocado to a number.

# %%
mapping = {'c':5 , 'G':1, 'F':3}
NBA['pos_as_num']=NBA.pos.map(mapping)
pd.plotting.scatter_matrix(NBA[['pos_as_num', 'pts', 'age', 'fg']]);

# %% [markdown]
# The end! Great job!!!
